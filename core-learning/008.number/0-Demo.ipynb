# %% [markdown]
# ### 008.NUMBER IS INT

# %%
a=1.32
a.is_integer() #false

# %% [markdown]
# ### 008.NUMBERS ABS

# %%
a=1.32000
abs(a)#1.32

# %% [markdown]
# ### 008.NUMBERS CEIL

# %%
import math
a=1.27
math.ceil(a) #2

# %% [markdown]
# ### 008.NUMBERS FLOOR

# %%
import math
a=1.27
math.floor(a) #1

# %% [markdown]
# ### 008.NUMBERS MAX

# %%
a=[1,2,3,4,5]
max(a)#5

# %% [markdown]
# ### 008.NUMBERS MIN

# %%
a=[1,2,3,4,5]
min(a)#1

# %% [markdown]
# ### 008.NUMBERS ROUND

# %%
a=7.27
round(a)#7
